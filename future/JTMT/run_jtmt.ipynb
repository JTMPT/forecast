# %%
# %run "W:\Projects\הסעת המונים\01_שלב ה\קבצי עבודה\תחזיות_דמוגרפיות\תחזיות_2050\קוד\join_kibolt_2050_Jewish_230707.ipynb"
# Out:
# C:\Users\gidon\Anaconda3\envs\geo_env\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\gidon\Anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:2196: UserWarning: `keep_geom_type=True` in overlay resulted in 13 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   return geopandas.overlay(

# %%
# %run "W:\Data\Forecast\creat_age_distribution\v_1\code\create_age_distribution_230719.ipynb"

# %%
# %run "W:\Projects\הסעת המונים\01_שלב ה\קבצי עבודה\תחזיות_דמוגרפיות\תחזיות_2050\קוד\230709_join_arab_jew_pop.ipynb"

# %%
# %run "W:\Projects\הסעת המונים\01_שלב ה\קבצי עבודה\תחזיות_דמוגרפיות\תחזיות_2050\קוד\creat_forecast_2050_230719.ipynb"
# Out:
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\1389629884.py:1: UserWarning: `keep_geom_type=True` in overlay resulted in 279 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   EMP_kibolet_by_taz=gpd.overlay(taz[['Taz_num','taz_area','geometry']],EMP_kibolet[['ID','emp_area','geometry']])
# ---------------------------
# 2025
# student before:  714557.0
# student after:  844618.0
# emp_from_student after:  120660.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  81185.0
# uni_students after:  92615.0
# growth_dorms:  1.140797633874793
# student_dorms before:  9345
# student_dorms after:  10661.0
# emp_from_uni_student before:  16056.0
# emp_from_uni_student after:  18114.0
# student_yeshiva before:  105573
# student_yeshiva after:  120279.90531272674
# student_yeshiva after:  120279.90531272674
# emp_from_Yeshiva_student before:  3921
# emp_from_Yeshiva_student after:  4467.217079472986
# yeshiva_dorms_pop_sum before:  35878
# yeshiva_dorms_pop_sum after:  40876.0
# emp_Education after:  143240.0
# emp_Education:  143220.0
# emp_okev:  190248.0
# emp_in_jtmt_area_without_mobile:  551477.0
# add_emp_not_okev:  31639.0
# emp_not_okev_current before:  186370.0
# emp_not_okev_current that should be:  218009.0
# add_emp_not_okev_kibolet:  35131.0
# add_emp_not_okev_filling:  0.9
# emp_not_okev_current after:  218009.0
# emp_not_okev_current after coversion to taz:  218009.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))
# ---------------------------
# 2030
# student before:  844618.0
# student after:  956528.0
# emp_from_student after:  136647.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  92615.0
# uni_students after:  104554.0
# growth_dorms:  1.1289047793832034
# student_dorms before:  10661.0
# student_dorms after:  12035.0
# emp_from_uni_student before:  18114.0
# emp_from_uni_student after:  20263.0
# student_yeshiva before:  120279.90531272674
# student_yeshiva after:  137924.92674961264
# student_yeshiva after:  137924.92674961264
# emp_from_Yeshiva_student before:  4467.217079472986
# emp_from_Yeshiva_student after:  5122.5563144481175
# yeshiva_dorms_pop_sum before:  40876.0
# yeshiva_dorms_pop_sum after:  46873.0
# emp_Education after:  162032.0
# emp_Education:  162008.0
# emp_okev:  210719.0
# emp_in_jtmt_area_without_mobile:  631465.0
# add_emp_not_okev:  40729.0
# emp_not_okev_current before:  218009.0
# emp_not_okev_current that should be:  258738.0
# add_emp_not_okev_kibolet:  46509.0
# add_emp_not_okev_filling:  0.88
# emp_not_okev_current after:  258738.0
# emp_not_okev_current after coversion to taz:  258738.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))
# ---------------------------
# 2035
# student before:  956528.0
# student after:  1085106.0
# emp_from_student after:  155015.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  104554.0
# uni_students after:  116411.0
# growth_dorms:  1.1134102446659184
# student_dorms before:  12035.0
# student_dorms after:  13400.0
# emp_from_uni_student before:  20263.0
# emp_from_uni_student after:  22397.0
# student_yeshiva before:  137924.92674961264
# student_yeshiva after:  157849.1380334435
# student_yeshiva after:  157849.1380334435
# emp_from_Yeshiva_student before:  5122.5563144481175
# emp_from_Yeshiva_student after:  5862.545065775643
# yeshiva_dorms_pop_sum before:  46873.0
# yeshiva_dorms_pop_sum after:  53644.0
# emp_Education after:  183275.0
# emp_Education:  183248.0
# emp_okev:  235642.0
# emp_in_jtmt_area_without_mobile:  727265.0
# add_emp_not_okev:  49638.0
# emp_not_okev_current before:  258738.0
# emp_not_okev_current that should be:  308376.0
# add_emp_not_okev_kibolet:  86529.0
# add_emp_not_okev_filling:  0.57
# emp_not_okev_current after:  308376.0
# emp_not_okev_current after coversion to taz:  308376.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))
# ---------------------------
# 2040
# student before:  1085106.0
# student after:  1217505.0
# emp_from_student after:  173929.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  116411.0
# uni_students after:  129818.0
# growth_dorms:  1.115169456989797
# student_dorms before:  13400.0
# student_dorms after:  14943.0
# emp_from_uni_student before:  22397.0
# emp_from_uni_student after:  24810.0
# student_yeshiva before:  157849.1380334435
# student_yeshiva after:  177684.19254973246
# student_yeshiva after:  177684.19254973246
# emp_from_Yeshiva_student before:  5862.545065775643
# emp_from_Yeshiva_student after:  6599.222518896886
# yeshiva_dorms_pop_sum before:  53644.0
# yeshiva_dorms_pop_sum after:  60384.0
# emp_Education after:  205339.0
# emp_Education:  205308.0
# emp_okev:  256027.0
# emp_in_jtmt_area_without_mobile:  827378.0
# add_emp_not_okev:  57667.0
# emp_not_okev_current before:  308376.0
# emp_not_okev_current that should be:  366043.0
# add_emp_not_okev_kibolet:  137306.0
# add_emp_not_okev_filling:  0.42
# emp_not_okev_current after:  366043.0
# emp_not_okev_current after coversion to taz:  366043.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))
# ---------------------------
# 2045
# student before:  1217505.0
# student after:  1270323.0
# emp_from_student after:  181475.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  129818.0
# uni_students after:  151768.0
# growth_dorms:  1.169076928555195
# student_dorms before:  14943.0
# student_dorms after:  17470.0
# emp_from_uni_student before:  24810.0
# emp_from_uni_student after:  28761.0
# student_yeshiva before:  177684.19254973246
# student_yeshiva after:  211660.22382221473
# student_yeshiva after:  211660.22382221473
# emp_from_Yeshiva_student before:  6599.222518896886
# emp_from_Yeshiva_student after:  7861.0983642304745
# yeshiva_dorms_pop_sum before:  60384.0
# yeshiva_dorms_pop_sum after:  71931.0
# emp_Education after:  218097.0
# emp_Education:  218061.0
# emp_okev:  274450.0
# emp_in_jtmt_area_without_mobile:  928799.0
# add_emp_not_okev:  70245.0
# emp_not_okev_current before:  366043.0
# emp_not_okev_current that should be:  436288.0
# add_emp_not_okev_kibolet:  171924.0
# add_emp_not_okev_filling:  0.41
# emp_not_okev_current after:  436288.0
# emp_not_okev_current after coversion to taz:  436288.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))
# ---------------------------
# 2050
# student before:  1270323.0
# student after:  1321312.0
# emp_from_student after:  188759.0
# dorms_vs_uni_students:  12.0 %
# uni_students before:  151768.0
# uni_students after:  161668.0
# growth_dorms:  1.0652340479692277
# student_dorms before:  17470.0
# student_dorms after:  18609.0
# emp_from_uni_student before:  28761.0
# emp_from_uni_student after:  30543.0
# student_yeshiva before:  211660.22382221473
# student_yeshiva after:  227746.09035736253
# student_yeshiva after:  227746.09035736253
# emp_from_Yeshiva_student before:  7861.0983642304745
# emp_from_Yeshiva_student after:  8458.530308802614
# yeshiva_dorms_pop_sum before:  71931.0
# yeshiva_dorms_pop_sum after:  77397.0
# emp_Education after:  227760.0
# emp_Education:  227722.0
# emp_okev:  287178.0
# emp_in_jtmt_area_without_mobile:  994379.0
# add_emp_not_okev:  43192.0
# emp_not_okev_current before:  436288.0
# emp_not_okev_current that should be:  479479.0
# add_emp_not_okev_kibolet:  162012.0
# add_emp_not_okev_filling:  0.27
# emp_not_okev_current after:  479479.0
# emp_not_okev_current after coversion to taz:  479479.0
# taz num under 0: []
# taz num duplicate: []
# yosh_unique: [0, 1]
# in_jerusalem_metropolin_unique: [1, 0]
# jerusalem_city_unique: [1, 0]
# sector_unique: ['arabs_behined_seperation_wall', 'Arab', 'Palestinian', 'U_Orthodox', 'Jewish']
# taz num with minus: []
# pop more then hh: []
# hh missing pop: []
# pop missing hh: []
# pop vs age dis Mistake: []
# taz num with age dis prob: []
# taz num with emp total prob: []
# taz num with emp dis prob: []
# taz num with pop_emp_employed worng : []
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz[col].sum(axis=1)-taz['pop']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['pop_check']=taz['pop_check'].round(0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=taz[col].sum(axis=1)-taz['emp_tot']
# C:\Users\gidon\AppData\Local\Temp\ipykernel_26644\2235942893.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taz['emp_check']=abs(taz['emp_check'].round(0))

# %%
# %run "W:\Projects\הסעת המונים\01_שלב ה\קבצי עבודה\תחזיות_דמוגרפיות\תחזיות_2050\jtmt\join_forecast\join_forecast.ipynb"

# %%
# %run "./fix_cbs_data_230717.ipynb"
# %run "./from_sa_cbs_to_ta_jtmt.ipynb"
# %run "./create_gov_student_num_by_muni.ipynb"
# %run "./prepare_students.ipynb"
# %run "./emp_current_year.ipynb"
# %run "./add_geo_info_and_exsport.ipynb"
# %run "./Determining_type_of_age_distribution_230719.ipynb"
# Out:
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3666940613.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '235652.6' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   group_pop_jtmt.loc['east_jeru_left','pop']=group_pop_delta.item()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\1360134725.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   hh_size_by_classification=drop_geo(stat).loc[(stat['aprt_20']>0)&(stat['STAT'].isin(cbs_not_lie_lst))].pivot_table(index='classification_name',aggfunc=sum)[['aprt_20','pop','count']]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\423562680.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   stat_by_muni_sum=drop_geo(stat).pivot_table(index='CR_PNIM',aggfunc=sum)[['pop_cbs','pop']]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3159188487.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 31.3225      20.58816099  23.03316663 ...  79.56155771  86.00171698
#  411.10230836]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   bld_point.loc[(bld_point['HEIGHT']-ceiling_height)<=0,'bld_m3']=bld_point['bld_area']
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3533048335.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   sum_bld_m3=pd.pivot_table(bld_point.drop(columns='centroid'),index=['Taz_num','STAT'],aggfunc=sum)[['bld_m3']].reset_index()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3687277795.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   sum_bld_m3_by_stat=sum_bld_m3.pivot_table(index='STAT',aggfunc=sum)[['bld_m3']].rename(columns={'bld_m3':'bld_m3_stat'}).reset_index()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\573162633.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   sum_bld_m3_by_stat=sum_bld_m3.pivot_table(index='STAT',aggfunc=sum)[['bld_m3']].rename(columns={'bld_m3':'bld_m3_stat_new'}).reset_index()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3759065189.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   taz=pd.pivot_table(taz,index='Taz_num',aggfunc=sum)
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\3236687485.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   shcl_with_taz_arab=shcl_with_taz.loc[shcl_with_taz['sector']==1].pivot_table(index='Taz_num',aggfunc=sum)[old_col]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2028788263.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   shcl_with_taz_hardi=shcl_with_taz.loc[shcl_with_taz['sector']==2].pivot_table(index='Taz_num',aggfunc=sum)[old_col]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2629452214.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   shcl_with_taz_Jewish=shcl_with_taz.loc[shcl_with_taz['sector']==3].pivot_table(index='Taz_num',aggfunc=sum)[old_col]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\551627819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sum_students_by_muni_sector_demand_add_from_gov_by_muni.loc[filter_condition, 'sum_add_students'] = 3000
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2539747398.py:3: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   student_arab_not_gov=student_arab_not_gov.pivot_table(index='Taz_num',aggfunc=sum)[['num_student']]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2039466339.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   taz['student_chardi_not_gov']=drop_geo(student_chardi_not_gov_with_taz).pivot_table(index='Taz_num',aggfunc=sum)[['num_students']]
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2892090057.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   uni_students_sum_by_taz=uni_students_with_taz[col].pivot_table(index='Taz_num',aggfunc=sum).reset_index()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\997828904.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   student_yeshiva_by_gender_taz=drop_geo(student_yeshiva).pivot_table(index=['Taz_num','gender'],aggfunc=sum).reset_index()
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\709779699.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 35.15       276.         300.08391068   8.1       ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taz.loc[(taz['main_secto']=='U_Orthodox')&(taz['kollim_demand']>taz['Yeshiva']),'add_from_kollim_demand']=taz['kollim_demand']-taz['Yeshiva']
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\219692974.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[8.53600000e-01 0.00000000e+00 2.77129000e+01 7.58928000e+01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.54923000e+01
#  2.69369000e+01 9.10830000e+00 5.25449000e+01 3.79852000e+01
#  0.00000000e+00 3.81404000e+01 3.42410000e+00 3.82859000e+01
#  2.68098300e+02 2.38911000e+01 3.50364000e+01 3.89455000e+01
#  4.01774000e+01 2.07871000e+01 0.00000000e+00 5.24576000e+01
#  9.88430000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.76000000e-02 0.00000000e+00
#  2.32800000e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.42493000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.68309000e+01 0.00000000e+00 3.93044000e+01 0.00000000e+00
#  4.53863000e+01 1.70720000e+00 3.11370000e+00 0.00000000e+00
#  4.49110000e+01 2.29599000e+01 1.54909000e+01 1.83718000e+01
#  0.00000000e+00 0.00000000e+00 5.43200000e-01 0.00000000e+00
#  5.43200000e-01 0.00000000e+00 7.76000000e-02 3.79076000e+01
#  0.00000000e+00 3.60452000e+01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 7.22650000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.17675000e+01
#  3.92171000e+01 4.28158000e+01 0.00000000e+00 6.92871000e+01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.29724000e+01
#  1.33084000e+01 0.00000000e+00 1.52581000e+01 6.69300000e+00
#  2.71600000e+00 7.73769000e+01 1.31920000e+00 5.76180000e+00
#  1.28428000e+01 0.00000000e+00 0.00000000e+00 6.16532000e+01
#  0.00000000e+00 2.70824000e+01 2.84889000e+01 0.00000000e+00
#  1.60341000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  5.83940000e+00 3.81210000e+00 4.43290000e+00 0.00000000e+00
#  0.00000000e+00 1.73630000e+01 3.71316000e+01 6.20800000e-01
#  9.57390000e+00 0.00000000e+00 0.00000000e+00 7.76000000e-02
#  4.21950000e+01 0.00000000e+00 1.61582600e+02 8.08204000e+01
#  6.14980000e+00 5.48729000e+01 7.14017000e+01 3.10594000e+01
#  8.56510000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 6.69300000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.92221100e+02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 4.25830000e+01 1.06860879e+03 3.43612800e+02
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.24943000e+01
#  0.00000000e+00 0.00000000e+00 5.76180000e+00 5.43200000e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.33576000e+01
#  0.00000000e+00 0.00000000e+00]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taz.loc[taz['main_secto']=="U_Orthodox",'pop_emp_employed']=taz['pop_emp']*0.97
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\1435860360.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[    -0.             -0.             -0.         -11635.64866814
#      -0.         -17215.61078682 -10973.05516632 -10335.108
#   -2984.73        -7324.52938563     -0.          -4420.27615026
#   -1072.98787009   -717.39194022 -24842.67710029 -31964.3863003
#    -135.79793411  -2805.43660252  -6966.41902264  -1283.17710303
#   -1204.79272932  -3662.64109449  -3024.17890551]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taz.loc[(taz['jew']==0)&(taz['okev']==1),'emp_okev']=taz['aprt_20']*okev_factor.loc['arab','city']
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\1806380584.py:5: UserWarning: `keep_geom_type=True` in overlay resulted in 279 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   EMP_kibolet_by_taz=gpd.overlay(taz.reset_index()[['Taz_num','taz_area','geometry']],EMP_kibolet)
# c:\Users\dpere\miniconda3\envs\creat_forecast_ad_hoc_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2666082859.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'חרדי צעיר' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   locals()['data_df_{}'.format(s)].at[index,'classification_name'] = closest_prototype
# c:\Users\dpere\miniconda3\envs\creat_forecast_ad_hoc_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2666082859.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'כללי מאוזן' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   locals()['data_df_{}'.format(s)].at[index,'classification_name'] = closest_prototype
# c:\Users\dpere\miniconda3\envs\creat_forecast_ad_hoc_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2666082859.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'מתנחלי מאוזן ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   locals()['data_df_{}'.format(s)].at[index,'classification_name'] = closest_prototype
# c:\Users\dpere\miniconda3\envs\creat_forecast_ad_hoc_env\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\dpere\AppData\Local\Temp\ipykernel_34944\2666082859.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'ערבי צעיר' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   locals()['data_df_{}'.format(s)].at[index,'classification_name'] = closest_prototype

# %%
# %run "./monitoring_df.ipynb"
# Out:
# C:\Users\gidon\AppData\Local\Temp\ipykernel_19296\3179375671.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   val = ((current_total - previous_total) / previous_total * 100.0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_19296\3179375671.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   val = ((current_total - previous_total) / previous_total * 100.0)
# C:\Users\gidon\AppData\Local\Temp\ipykernel_19296\3179375671.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   val = ((current_total - previous_total) / previous_total * 100.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_19296\929199316.py:2
#       1 # חישוב מועסקים עוקב אוכלוסיה לפי שכונות בירושלים כל חומש בכל תרחיש
# ----> 2 monitoring_df = add_total_sum_by_type_row(schn_names, 'emp_okev', 'SCHN_NAME')
# ...
